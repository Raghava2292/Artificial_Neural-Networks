# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('gas_turbines.csv')
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
X = data.drop('TEY', axis = 1)
y = data[['TEY']]

# %%
X
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
y
# Out:
#           TEY
# 0      114.70
# 1      114.72
# 2      114.71
# 3      114.72
# 4      114.72
# ...       ...
# 15034  111.61
# 15035  111.78
# 15036  110.19
# 15037  110.74
# 15038  111.58
#
# [15039 rows x 1 columns]

# %% [markdown]
# ------------------
#
# Before training the model it would be better to find the proper hyperparameters that would gives the best possible results. So tuning of different hyperparameters is needed before training the model. These parameters are batch size, number of epochs, drop out rate, learning rate, number of neurons in hidden layers, the activation function and the kernel initializer.

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.optimizers import Adam

# %%
# create model
# kernel_initializer is the weight initializer
# linear or step activation for regression problems.
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=10, kernel_initializer='random_uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='random_uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='random_uniform', activation='linear'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['MeanSquaredError'])
    return model

# %%
# Create the model
model = KerasRegressor(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END ....batch_size=10, epochs=10;, score=-2.130 total time=  25.7s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END ....batch_size=10, epochs=10;, score=-1.101 total time=  22.7s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END ....batch_size=10, epochs=10;, score=-4.918 total time=  22.6s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END ....batch_size=10, epochs=10;, score=-3.967 total time=  22.8s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END ....batch_size=10, epochs=10;, score=-1.741 total time=  23.5s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END ....batch_size=10, epochs=50;, score=-7.365 total time= 1.9min
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END ...batch_size=10, epochs=50;, score=-18.867 total time= 1.9min
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END ...batch_size=10, epochs=50;, score=-10.231 total time= 2.0min
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END ....batch_size=10, epochs=50;, score=-1.037 total time= 2.0min
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END ....batch_size=10, epochs=50;, score=-1.038 total time= 1.9min
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ...batch_size=10, epochs=100;, score=-1.829 total time= 3.7min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ...batch_size=10, epochs=100;, score=-0.906 total time= 3.7min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ...batch_size=10, epochs=100;, score=-5.606 total time= 3.7min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ...batch_size=10, epochs=100;, score=-3.940 total time= 3.7min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ...batch_size=10, epochs=100;, score=-3.735 total time= 3.7min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END ....batch_size=20, epochs=10;, score=-4.009 total time=  14.2s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END ....batch_size=20, epochs=10;, score=-1.163 total time=  12.9s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END ....batch_size=20, epochs=10;, score=-2.414 total time=  12.6s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END ....batch_size=20, epochs=10;, score=-1.381 total time=  12.5s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END ....batch_size=20, epochs=10;, score=-3.067 total time=  12.5s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END ....batch_size=20, epochs=50;, score=-3.283 total time=  56.7s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END ....batch_size=20, epochs=50;, score=-0.802 total time=  57.9s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END ..batch_size=20, epochs=50;, score=-315.178 total time=  57.1s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END ....batch_size=20, epochs=50;, score=-1.669 total time=  56.8s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END ....batch_size=20, epochs=50;, score=-1.386 total time=  56.6s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ...batch_size=20, epochs=100;, score=-2.105 total time= 1.9min
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ...batch_size=20, epochs=100;, score=-1.272 total time= 1.9min
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ...batch_size=20, epochs=100;, score=-1.296 total time= 1.9min
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ...batch_size=20, epochs=100;, score=-0.913 total time= 1.9min
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ...batch_size=20, epochs=100;, score=-3.667 total time= 1.9min
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END ....batch_size=40, epochs=10;, score=-5.524 total time=   6.9s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END ....batch_size=40, epochs=10;, score=-2.517 total time=   6.7s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END ....batch_size=40, epochs=10;, score=-2.157 total time=   7.1s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END ....batch_size=40, epochs=10;, score=-1.993 total time=   6.5s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END ....batch_size=40, epochs=10;, score=-2.264 total time=   6.9s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END ....batch_size=40, epochs=50;, score=-2.905 total time=  29.0s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END ....batch_size=40, epochs=50;, score=-0.776 total time=  28.4s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END ....batch_size=40, epochs=50;, score=-2.124 total time=  28.6s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END ....batch_size=40, epochs=50;, score=-6.211 total time=  28.5s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END ....batch_size=40, epochs=50;, score=-3.121 total time=  28.6s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END ...batch_size=40, epochs=100;, score=-1.785 total time=  55.4s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END ...batch_size=40, epochs=100;, score=-1.186 total time=  56.3s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END ...batch_size=40, epochs=100;, score=-2.298 total time=  55.9s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END ...batch_size=40, epochs=100;, score=-1.455 total time= 1.0min
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END ...batch_size=40, epochs=100;, score=-2.201 total time= 1.0min

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -1.7848973751068116, using {'batch_size': 40, 'epochs': 100}
# -2.771139144897461,1.4353050194003099 with: {'batch_size': 10, 'epochs': 10}
# -7.7074696063995365,6.63347295802528 with: {'batch_size': 10, 'epochs': 50}
# -3.20300350189209,1.6589476718558613 with: {'batch_size': 10, 'epochs': 100}
# -2.4067633628845213,1.0584395315709842 with: {'batch_size': 20, 'epochs': 10}
# -64.46365877389908,125.35995047395618 with: {'batch_size': 20, 'epochs': 50}
# -1.8505537033081054,0.988354781077145 with: {'batch_size': 20, 'epochs': 100}
# -2.8908901453018188,1.327449591142401 with: {'batch_size': 40, 'epochs': 10}
# -3.0274120688438417,1.7914138677752072 with: {'batch_size': 40, 'epochs': 50}
# -1.7848973751068116,0.42526473706600415 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(12,input_dim = 10,kernel_initializer = 'random_uniform',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(8,input_dim = 12,kernel_initializer = 'random_uniform',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['MeanSquaredError'])
    return model

# Create the model

model = KerasRegressor(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-2.365 total time=  53.6s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-1.046 total time=  55.5s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-1.281 total time=  56.6s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-0.997 total time=  57.2s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-1.385 total time=  57.9s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-1.931 total time=  58.5s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-0.875 total time=  58.7s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-1.561 total time= 1.0min
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-0.993 total time= 1.1min
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-1.761 total time= 1.0min
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-334.620 total time= 1.1min
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-126.553 total time= 1.1min
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-2.605 total time= 1.0min
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-6.160 total time=  59.1s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-280.767 total time= 1.0min
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-14.698 total time= 1.0min
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-3.129 total time= 1.0min
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-37.026 total time= 1.2min
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-7.957 total time= 1.1min
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-152.886 total time= 1.0min
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-39.661 total time= 1.1min
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-9.815 total time= 1.1min
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-11.179 total time= 1.0min
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-13.271 total time= 1.0min
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-15.653 total time= 1.0min
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-340.620 total time= 1.1min
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-130.549 total time=  59.0s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-314.608 total time=  59.1s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-238.300 total time=  58.9s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-263.212 total time= 1.0min
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-11.880 total time= 1.0min
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-71.354 total time=  59.7s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-45.875 total time=  58.6s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-479.560 total time=  58.9s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-22.878 total time= 1.0min
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-343.698 total time=  59.9s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-50.028 total time=  59.8s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-314.378 total time=  58.0s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-49.403 total time=  58.5s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-75.229 total time=  59.0s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-337.828 total time=  59.5s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-127.748 total time=  59.6s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-312.104 total time=  58.7s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-235.686 total time=  58.5s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-257.462 total time=  58.8s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -1.4148911476135253, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -1.4148911476135253,0.49638269974657256 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -1.4243341445922852,0.4186719196772588 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# -150.14105911254882,137.2219762882828 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# -43.13923797607422,56.08800080020923 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# -17.915695190429688,11.050686156595106 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# -257.4578155517578,73.05885033512811 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# -126.30947418212891,177.8018779187163 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# -166.54702606201172,133.3227260674198 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# -254.16554412841796,73.06178003994918 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(12,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.0))
    model.add(Dense(8,input_dim = 12,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['MeanSquaredError'])
    return model

# Create the model

model = KerasRegressor(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Define the grid search parameters
activation_function = ['selu','relu','step','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=selu, init=uniform.....................
# [CV 1/5; 1/12] END activation_function=selu, init=uniform;, score=-2.055 total time= 1.0min
# [CV 2/5; 1/12] START activation_function=selu, init=uniform.....................
# [CV 2/5; 1/12] END activation_function=selu, init=uniform;, score=-0.517 total time= 1.1min
# [CV 3/5; 1/12] START activation_function=selu, init=uniform.....................
# [CV 3/5; 1/12] END activation_function=selu, init=uniform;, score=-1.351 total time= 1.1min
# [CV 4/5; 1/12] START activation_function=selu, init=uniform.....................
# [CV 4/5; 1/12] END activation_function=selu, init=uniform;, score=-2.288 total time= 1.1min
# [CV 5/5; 1/12] START activation_function=selu, init=uniform.....................
# [CV 5/5; 1/12] END activation_function=selu, init=uniform;, score=-1.198 total time= 1.1min
# [CV 1/5; 2/12] START activation_function=selu, init=normal......................
# [CV 1/5; 2/12] END activation_function=selu, init=normal;, score=-2.636 total time=  58.9s
# [CV 2/5; 2/12] START activation_function=selu, init=normal......................
# [CV 2/5; 2/12] END activation_function=selu, init=normal;, score=-0.580 total time= 1.1min
# [CV 3/5; 2/12] START activation_function=selu, init=normal......................
# [CV 3/5; 2/12] END activation_function=selu, init=normal;, score=-0.883 total time= 1.0min
# [CV 4/5; 2/12] START activation_function=selu, init=normal......................
# [CV 4/5; 2/12] END activation_function=selu, init=normal;, score=-0.649 total time= 1.1min
# [CV 5/5; 2/12] START activation_function=selu, init=normal......................
# [CV 5/5; 2/12] END activation_function=selu, init=normal;, score=-1.049 total time= 1.2min
# [CV 1/5; 3/12] START activation_function=selu, init=zero........................
# [CV 1/5; 3/12] END activation_function=selu, init=zero;, score=-338.515 total time= 1.0min
# [CV 2/5; 3/12] START activation_function=selu, init=zero........................
# [CV 2/5; 3/12] END activation_function=selu, init=zero;, score=-132.351 total time= 1.2min
# [CV 3/5; 3/12] START activation_function=selu, init=zero........................
# [CV 3/5; 3/12] END activation_function=selu, init=zero;, score=-317.332 total time= 1.0min
# [CV 4/5; 3/12] START activation_function=selu, init=zero........................
# [CV 4/5; 3/12] END activation_function=selu, init=zero;, score=-236.169 total time= 1.0min
# [CV 5/5; 3/12] START activation_function=selu, init=zero........................
# [CV 5/5; 3/12] END activation_function=selu, init=zero;, score=-260.228 total time=  57.9s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=-3.164 total time=  56.1s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=-1.805 total time=  56.6s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=-1.307 total time= 1.1min
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=-0.982 total time= 1.0min
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=-1.515 total time= 1.0min
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=-3.799 total time=  59.8s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=-0.848 total time= 1.0min
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=-1.332 total time=  58.4s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=-1.172 total time=  58.8s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=-10569.481 total time= 1.0min
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=-11580.037 total time=  59.5s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=-10108.878 total time=  59.5s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=-12090.729 total time=  58.9s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=-11328.115 total time=  58.0s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=-10569.521 total time= 1.0min
# [CV 1/5; 7/12] START activation_function=step, init=uniform.....................
# [CV 1/5; 7/12] END activation_function=step, init=uniform;, score=nan total time=   0.0s
# [CV 2/5; 7/12] START activation_function=step, init=uniform.....................
# [CV 2/5; 7/12] END activation_function=step, init=uniform;, score=nan total time=   0.0s
# [CV 3/5; 7/12] START activation_function=step, init=uniform.....................
# [CV 3/5; 7/12] END activation_function=step, init=uniform;, score=nan total time=   0.0s
# [CV 4/5; 7/12] START activation_function=step, init=uniform.....................
# [CV 4/5; 7/12] END activation_function=step, init=uniform;, score=nan total time=   0.0s
# [CV 5/5; 7/12] START activation_function=step, init=uniform.....................
# [CV 5/5; 7/12] END activation_function=step, init=uniform;, score=nan total time=   0.0s
# [CV 1/5; 8/12] START activation_function=step, init=normal......................
# [CV 1/5; 8/12] END activation_function=step, init=normal;, score=nan total time=   0.0s
# [CV 2/5; 8/12] START activation_function=step, init=normal......................
# [CV 2/5; 8/12] END activation_function=step, init=normal;, score=nan total time=   0.0s
# [CV 3/5; 8/12] START activation_function=step, init=normal......................
# [CV 3/5; 8/12] END activation_function=step, init=normal;, score=nan total time=   0.0s
# [CV 4/5; 8/12] START activation_function=step, init=normal......................
# [CV 4/5; 8/12] END activation_function=step, init=normal;, score=nan total time=   0.0s
# [CV 5/5; 8/12] START activation_function=step, init=normal......................
# [CV 5/5; 8/12] END activation_function=step, init=normal;, score=nan total time=   0.0s
# [CV 1/5; 9/12] START activation_function=step, init=zero........................
# [CV 1/5; 9/12] END activation_function=step, init=zero;, score=nan total time=   0.0s
# [CV 2/5; 9/12] START activation_function=step, init=zero........................
# [CV 2/5; 9/12] END activation_function=step, init=zero;, score=nan total time=   0.0s
# [CV 3/5; 9/12] START activation_function=step, init=zero........................
# [CV 3/5; 9/12] END activation_function=step, init=zero;, score=nan total time=   0.0s
# [CV 4/5; 9/12] START activation_function=step, init=zero........................
# [CV 4/5; 9/12] END activation_function=step, init=zero;, score=nan total time=   0.0s
# [CV 5/5; 9/12] START activation_function=step, init=zero........................
# [CV 5/5; 9/12] END activation_function=step, init=zero;, score=nan total time=   0.0s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=-2.788 total time=  58.1s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=-0.705 total time=  58.5s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=-1.456 total time= 1.0min
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=-1.268 total time=  58.6s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=-1.389 total time=  59.0s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=-5.138 total time=  59.5s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=-0.746 total time=  58.3s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=-1.900 total time= 1.2min
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=-1.570 total time= 1.1min
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=-1.429 total time= 1.4min
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=-339.510 total time= 1.4min
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=-134.246 total time= 1.3min
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=-313.208 total time= 1.3min
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=-236.137 total time= 1.2min
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=-261.602 total time= 1.2min

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -1.1593136191368103, using {'activation_function': 'selu', 'init': 'normal'}
# -1.4818315625190734,0.6336394670977893 with: {'activation_function': 'selu', 'init': 'uniform'}
# -1.1593136191368103,0.7570609539186154 with: {'activation_function': 'selu', 'init': 'normal'}
# -256.91883850097656,72.47961344641651 with: {'activation_function': 'selu', 'init': 'zero'}
# -1.7546372771263123,0.7541050332907008 with: {'activation_function': 'relu', 'init': 'uniform'}
# -2115.3265095114707,4227.077598376048 with: {'activation_function': 'relu', 'init': 'normal'}
# -11135.455859375,710.1353446034816 with: {'activation_function': 'relu', 'init': 'zero'}
# nan,nan with: {'activation_function': 'step', 'init': 'uniform'}
# nan,nan with: {'activation_function': 'step', 'init': 'normal'}
# nan,nan with: {'activation_function': 'step', 'init': 'zero'}
# -1.5211346387863158,0.6863150588043643 with: {'activation_function': 'linear', 'init': 'uniform'}
# -2.156789982318878,1.537259513308775 with: {'activation_function': 'linear', 'init': 'normal'}
# -256.94057312011716,71.40325804048224 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 10,kernel_initializer = 'normal',activation = 'selu'))
    model.add(Dropout(0.0))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'normal',activation = 'selu'))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['MeanSquaredError'])
    return model

# Create the model

model = KerasRegressor(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ........neuron1=4, neuron2=2;, score=-4.303 total time=  41.5s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END ......neuron1=4, neuron2=2;, score=-105.961 total time=  39.5s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END ......neuron1=4, neuron2=2;, score=-459.350 total time=  39.6s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END ......neuron1=4, neuron2=2;, score=-237.138 total time=  41.5s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END ........neuron1=4, neuron2=2;, score=-2.032 total time=  38.3s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END ........neuron1=4, neuron2=4;, score=-2.358 total time=  34.4s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END ........neuron1=4, neuron2=4;, score=-0.663 total time=  33.8s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END ........neuron1=4, neuron2=4;, score=-1.791 total time=  35.8s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END ........neuron1=4, neuron2=4;, score=-0.681 total time=  38.6s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END ........neuron1=4, neuron2=4;, score=-2.494 total time=  36.8s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END ........neuron1=4, neuron2=8;, score=-1.049 total time=  58.3s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END ........neuron1=4, neuron2=8;, score=-0.583 total time=  57.7s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END ........neuron1=4, neuron2=8;, score=-2.245 total time= 1.1min
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END ........neuron1=4, neuron2=8;, score=-0.677 total time= 1.1min
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END ........neuron1=4, neuron2=8;, score=-0.898 total time= 1.1min
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END ......neuron1=8, neuron2=2;, score=-440.282 total time= 1.0min
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END ......neuron1=8, neuron2=2;, score=-115.153 total time= 1.1min
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END ........neuron1=8, neuron2=2;, score=-1.285 total time= 1.1min
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END ........neuron1=8, neuron2=2;, score=-0.906 total time= 1.3min
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END ........neuron1=8, neuron2=2;, score=-1.522 total time= 1.3min
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END ........neuron1=8, neuron2=4;, score=-1.623 total time= 1.1min
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END ........neuron1=8, neuron2=4;, score=-0.560 total time= 1.1min
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END ........neuron1=8, neuron2=4;, score=-1.117 total time= 1.2min
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END ........neuron1=8, neuron2=4;, score=-1.443 total time= 1.2min
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END ........neuron1=8, neuron2=4;, score=-0.898 total time= 1.0min
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END ........neuron1=8, neuron2=8;, score=-2.084 total time= 1.1min
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END ........neuron1=8, neuron2=8;, score=-0.974 total time= 1.0min
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END ........neuron1=8, neuron2=8;, score=-1.145 total time= 1.1min
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END ........neuron1=8, neuron2=8;, score=-0.661 total time=  59.8s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END ......neuron1=8, neuron2=8;, score=-259.292 total time=  58.1s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END .......neuron1=16, neuron2=2;, score=-4.026 total time=  57.2s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END .......neuron1=16, neuron2=2;, score=-0.790 total time=  56.7s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END .......neuron1=16, neuron2=2;, score=-1.873 total time=  57.8s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END .......neuron1=16, neuron2=2;, score=-1.125 total time=  56.8s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END .......neuron1=16, neuron2=2;, score=-1.531 total time=  56.3s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END .......neuron1=16, neuron2=4;, score=-2.183 total time=  56.2s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END .......neuron1=16, neuron2=4;, score=-1.152 total time=  56.4s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END .......neuron1=16, neuron2=4;, score=-0.859 total time=  55.9s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END .......neuron1=16, neuron2=4;, score=-0.758 total time=  56.2s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END .......neuron1=16, neuron2=4;, score=-0.879 total time=  56.2s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END .......neuron1=16, neuron2=8;, score=-1.441 total time=  57.0s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END .......neuron1=16, neuron2=8;, score=-0.865 total time=  56.4s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END .......neuron1=16, neuron2=8;, score=-1.617 total time=  58.2s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END .......neuron1=16, neuron2=8;, score=-1.699 total time=  56.9s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END .......neuron1=16, neuron2=8;, score=-1.295 total time=  56.9s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -1.0902352571487426, using {'neuron1': 4, 'neuron2': 8}
# -161.75670356750487,171.84930845206662 with: {'neuron1': 4, 'neuron2': 2}
# -1.5975115180015564,0.7914459302617419 with: {'neuron1': 4, 'neuron2': 4}
# -1.0902352571487426,0.6002406447627366 with: {'neuron1': 4, 'neuron2': 8}
# -111.82935471534729,170.04939707121218 with: {'neuron1': 8, 'neuron2': 2}
# -1.128126585483551,0.3792679431769979 with: {'neuron1': 8, 'neuron2': 4}
# -52.83115631341934,103.23158390174103 with: {'neuron1': 8, 'neuron2': 8}
# -1.8691255569458007,1.1389385931474956 with: {'neuron1': 16, 'neuron2': 2}
# -1.1661030292510985,0.5249118698930128 with: {'neuron1': 16, 'neuron2': 4}
# -1.3833178281784058,0.29450956237060333 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, mean_squared_error

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(4,input_dim = 10,kernel_initializer = 'normal',activation = 'selu'))
    model.add(Dropout(0.0))
    model.add(Dense(8,input_dim = 4,kernel_initializer = 'normal',activation = 'selu'))
    model.add(Dropout(0.0))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['MeanSquaredError'])
    return model

# Create the model

model = KerasRegressor(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Fitting the model

model.fit(X,y)

# Predicting using trained model

y_predict = model.predict(X)

# Printing the metrics
print(mean_squared_error(y,y_predict))
# Out:
# 0.8519874463250975
